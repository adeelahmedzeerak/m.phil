# %% [markdown]
# # <center>CS568:Deep Learning</center>  <center>Fall 2020</center>
# ## Recitation 1 - Test 1
#
# **Total marks**: 20
#
# **Deadline**: 29 January, 2020 before 12.00 pm

# %% [markdown]
# Make two 1D arrays 'u' and 'v' consisting of 3 uniform random numbers between 0 and 2 each. (**0.5 mark**)

# %% [markdown]
# Compute the lengths of vectors 'u' and 'v'. Vector lenghts are also called *magnitudes* or *norms*. (**0.5 mark**)

# %% [markdown]
# Compute the dot-product of 'u' and 'v'. (**0.5 mark**)

# %% [markdown]
# Make a 2D array 'M' of size (2,3) containing uniform random numbers between 0 and 1. (**1 mark**)

# %% [markdown]
# Compute the matrix-vector product of 'M' and 'u'. (**0.5 mark**)

# %% [markdown]
# Make an array 'A' consisting of a (3,4) array, a (2,4) array and a (4,4) array. All 3 arrays should contain random integers less than 9. (**1 mark**)

# %% [markdown]
# Pad the three arrays in 'A' to make a tensor array 'B'. Padding should be at the top with constant value of -1. (**1 marks**)

# %% [markdown]
# Stack the arrays in 'A' vertically. (**1 mark**)

# %% [markdown]
# Stack the arrays in 'B' horizontally using only 1 line of code containing a for loop. (**1 marks**)

# %% [markdown]
# Create a matrix **A** of size (3,5) with 0 mean and 5 standard deviation. (**1 mark**)

# %% [markdown]
# Set all the elements in first row of **A** to 7.
# Set all the elements in second row of **A** to -2.
# Set the element in third row and second column of **A** to 9. (**1 mark**)

# %% [markdown]
# Subtract the mean of each row of matrix **A**. (**1 mark**)

# %% [markdown]
# Create a vector **a** of size 30 with values ranging from 60 to 89. (**1 mark**)

# %% [markdown]
# Create a (5,5) matrix **M** with values ranging from 0 to 24. (**1 mark**)

# %% [markdown]
# Make a (3,3) matrix **N** with 5 on the border and 0 inside. (**1 mark**)

# %% [markdown]
# Create a matrix **P** of size (3,4) with random integer values. (**1 mark**)

# %% [markdown]
# Create a 3-D array **L** with five on the diagonal and zeros elsewhere. (**1 mark**)

# %% [markdown]
# Create a class 'calculator' with the following functions to compute: **(5 marks)**
# - the dot product between two vectors
# - the cross product between two vectors
# - the length (norm) of the vector
# - matrix-vector product of a matrix and vector
# - the mean squared error between two vectors
